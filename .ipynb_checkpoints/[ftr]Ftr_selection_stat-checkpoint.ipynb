# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn.preprocessing import StandardScaler

from sklearn.feature_selection import mutual_info_classif
from sklearn.tree import DecisionTreeClassifier
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier

import scipy.stats as stats

# %%
import xgboost as xgb

# %%
X=pd.read_csv('x_train.csv',delimiter=";",header=None,names=['f'+str(i) for i in range (223)])
y=pd.read_csv('y_train.csv',names=['class'])
y=y['class']
X_test=pd.read_csv('x_test.csv',delimiter=";",header=None,names=['f'+str(i) for i in range (223)])

# %% [markdown]
# # Baseline

# %%
rf=RandomForestClassifier(max_features='auto',n_estimators=300,max_depth=100,random_state=42)
print (np.mean(cross_val_score(rf, X, y, cv=5)))
# Out:
# 0.557454376621

# %% [markdown]
# # Отбор фич
# Пусть $X$ - некий набор признаков
# 1. Считаем Взаимную информацию между признаками и целевой переменной.
# Удаляем из $X$ все признаки $f_i$, у которых ВИ меньше ПорогаИнформации
# Получаем набор признаков $X_1$
# 2. Далее удаляем из $X_1$ признаки $f_i$, если найдется такой признак $f_j$, что корреляция между ними больше  больше ПорогаКорреляции, а ВИ у $f_j$ больше

# %% [markdown]
# ### Отбор на основе ВЗАИМНОЙ ИНФОРМАЦИИ

# %%
def make_selection(X,mi_threshold,corr_threshold):
    X_sel=X.copy()
    # Считаем взаимную информацию
    mi=mutual_info_classif(X_sel,y,n_neighbors=5,random_state=42)
    # Удаляем признаки с ВИ меньше порога
    X_sel.drop(X_sel.columns[mi<mi_threshold],axis=1,inplace=True)
    print ("ftr qty after remove on MI: "+str(X_sel.shape[1]))
    # Формируем список признаков в порядке убывания ВИ
    cols=pd.Series(data=mi,index=X.columns).sort_values(ascending=False).index
    # Обходим признаки
    for ftr1 in cols:
        for ftr2 in cols: 
            if (ftr1==ftr2)|(not(ftr1 in list(X_sel.columns)))|(not(ftr2 in list(X_sel.columns))):
                continue
            corr,pvalue= stats.pearsonr(X_sel[ftr1],X_sel[ftr2])
            if abs(corr)>=corr_threshold:
                X_sel.drop(labels=ftr2,axis=1,inplace=True)     
    print ("ftr qty after remove on CORR: "+str(X_sel.shape[1]))
    return X_sel

# %%
# Порог ВИ
mi_threshold=0.03
corr_threshold=0.75
X_sel=make_selection(X,mi_threshold,corr_threshold)
print (X_sel.columns)
# Out:
# ftr qty after remove on MI: 82
# ftr qty after remove on CORR: 15
# Index(['f11', 'f12', 'f22', 'f79', 'f82', 'f96', 'f133', 'f138', 'f143',
#        'f147', 'f152', 'f156', 'f182', 'f187', 'f200'],
#       dtype='object')

# %%
X_sel.columns
# Out:
# Index(['f0', 'f5', 'f6', 'f11', 'f12', 'f13', 'f17', 'f18', 'f22', 'f23',
#        'f26', 'f27', 'f30', 'f36', 'f41', 'f46', 'f47', 'f49', 'f51', 'f54',
#        'f55', 'f59', 'f61', 'f62', 'f63', 'f70', 'f72', 'f73', 'f76', 'f78',
#        'f79', 'f81', 'f82', 'f89', 'f94', 'f96', 'f103', 'f108', 'f109',
# 3482 -1.250764 -1.636132  -0.744386  1.051477  0.003266  0.042992 -2.265595
# 3483  2.102938  1.400947   2.534196 -0.212402 -0.029957 -0.059418  1.029392
# 3484 -0.999236 -0.303695   0.785842  1.139152 -0.010023 -0.017249  0.931981
# 3485 -0.412338  1.408539  -1.542840  0.814478  0.076356 -0.191948  2.292125
# 3486 -0.747709 -0.295629  -0.058992  0.787493 -0.010023 -0.035321 -0.798502
# 3487 -0.160811  0.653694   1.393104  0.875458  0.059744 -0.119659  2.877259
# 3488  0.006874  0.886639   0.920227  0.320919 -0.008362  0.042992  2.025274
#
#           f200
# 0     0.712210
# 1     0.464518
# 2    -1.499324
# 3    -1.393170
# 4    -0.066250
# 5     1.119132
# 6    -1.127786
# 7    -1.163171
# 8     1.384516
# 9    -0.172404
# 10    0.836056
# 11   -1.180863
# 12   -1.304709
# 13    0.128365
# 14   -0.137019
# 15    0.004519
# 16   -1.322401
# 17    1.136824
# 18   -1.410863
# 19   -0.313942
# 20    2.481437
# 21    0.729902
# 22    1.189901
# 23    0.287595
# 24    1.136824
# 25    0.552979
# 26    1.189901
# 27   -1.605478
# 28    0.004519
# 29    0.305288
# ...        ...
# 3459  1.800285
# 3460  0.570672
# 3461  0.446826
# 3462  1.296055
# 3463 -1.163171
# 3464 -0.986248
# 3465 -1.074710
# 3466 -0.030865
# 3467  1.455285
# 3468 -1.074710
# 3469 -0.473172
# 3470  0.782979
# 3471  0.358364
# 3472 -0.367019
# 3473  0.499903
# 3474  0.039904
# 3475 -0.172404
# 3476 -1.039325
# 3477 -0.420095
# 3478 -1.251632
# 3479  0.057596
# 3480  0.429134
# 3481  1.189901
# 3482  1.349132
# 3483 -0.313942
# 3484  1.649900
# 3485 -1.764708
# 3486  1.136824
# 3487 -1.110094
# 3488  0.446826
#
# [3489 rows x 15 columns]

# %% [markdown]
# Считаем модель

# %%
rf=RandomForestClassifier(max_features='auto',n_estimators=300,max_depth=100,random_state=42)
print (np.mean(cross_val_score(rf, X_sel, y, cv=5)))
# Out:
# 0.603320745272

# %% [markdown]
# # Отбор на основе Корреляции

# %%
xcorr=X.corr()
corr_threshold=0.65
cor_cols=list()
for i in range(len(xcorr)):
    cor_group=list()
    for j in range(len(xcorr)):
        if j==i: continue
        if abs(xcorr.iloc[i,j])>=corr_threshold:
            #print (xcorr.index[i],xcorr.index[j],cor_val)
            if not(xcorr.index[i] in cor_group):
                cor_group.append(xcorr.index[i])
            if not(xcorr.index[j] in cor_group):
                cor_group.append(xcorr.index[j])
    if len(cor_group)>0:
        cor_group.sort()
        cor_cols.append(cor_group)
print (cor_cols)
# Out:
'f57', 'f58', 'f66', 'f69', 'f7', 'f74', 'f76', 'f81', 'f87', 'f89', 'f94', 'f96'], ['f113', 'f122', 'f124', 'f126', 'f127', 'f131', 'f136', 'f137', 'f139', 'f146', 'f147', 'f148', 'f15', 'f154', 'f162', 'f165', 'f172', 'f176', 'f177', 'f180', 'f220', 'f33', 'f47', 'f49', 'f77', 'f8', 'f84', 'f85', 'f92', 'f99'], ['f0', 'f108', 'f109', 'f113', 'f114', 'f138', 'f142', 'f150', 'f152', 'f153', 'f163', 'f164', 'f168', 'f17', 'f171', 'f172', 'f174', 'f179', 'f18', 'f184', 'f188', 'f205', 'f206', 'f208', 'f213', 'f221', 'f26', 'f27', 'f36', 'f41', 'f5', 'f59', 'f6', 'f63', 'f70', 'f72', 'f79', 'f89'], ['f0', 'f108', 'f109', 'f114', 'f138', 'f142', 'f150', 'f152', 'f153', 'f163', 'f164', 'f168', 'f17', 'f171', 'f174', 'f179', 'f18', 'f184', 'f188', 'f205', 'f206', 'f208', 'f213', 'f221', 'f26', 'f27', 'f36', 'f41', 'f5', 'f59', 'f6', 'f63', 'f70', 'f72', 'f79', 'f89'], ['f1', 'f102', 'f103', 'f104', 'f105', 'f107', 'f111', 'f117', 'f118', 'f121', 'f128', 'f129', 'f13', 'f133', 'f144', 'f167', 'f170', 'f185', 'f186', 'f19', 'f190', 'f199', 'f2', 'f200', 'f201', 'f215', 'f216', 'f218', 'f219', 'f32', 'f35', 'f46', 'f66', 'f69', 'f7', 'f73', 'f74', 'f76', 'f81', 'f87', 'f94'], ['f112', 'f116', 'f120', 'f130', 'f143', 'f158', 'f214', 'f22', 'f23', 'f43', 'f51', 'f54', 'f55', 'f57', 'f82', 'f98'], ['f0', 'f112', 'f120', 'f135', 'f138', 'f157', 'f158', 'f183', 'f193', 'f198', 'f208', 'f214', 'f217', ...

# %%
good_ftr=list()
bad_ftr=list()
# Удаляем дубли
for c in cor_cols:
    ftr_ser=pd.Series()
    for ftr in c:
        mi_ftr=mi[int(ftr[1:])]
        ftr_ser[ftr]=mi_ftr
    ftr_ser.sort_values(ascending=False,inplace=True)
    #print("ser")
    #print (ftr_ser.index[1:])
    bad_ftr.extend(list(ftr_ser.index[1:]))
    good_ftr.append(ftr_ser.index[0])
# Избавляемся от дубликатов
good_ftr = list(set(good_ftr))
good_ftr.sort()
bad_ftr = list(set(bad_ftr))
good_ftr.sort()
print ("Ftr with high mi=",good_ftr)
print ("Ftr to remove=",bad_ftr)
# Out:
# Ftr with high mi= ['f82']
# Ftr to remove= ['f22']

# %% [markdown]
# Удаляем фичи с высокой корреляцией

# %%
X.drop(labels=bad_ftr,axis=1,inplace=True)

# %% [markdown]
# Отображаем матрицу коррелцяции после удаления фич

# %%
sns.set(context="paper", font="monospace")
plt.figure(figsize=(100, 100))
sns_heatmap = sns.heatmap(X.corr(), vmax=.8,annot=True, ffmt=".2f", linewidths=.5)
plt.show()

# %% [markdown]
# Строим модель

# %%
rf=RandomForestClassifier(max_features='auto',n_estimators=300,max_depth=100,random_state=42)
print (np.mean(cross_val_score(rf, X, y, cv=5)))
# Out:
# 0.614507490978

# %%
print(list(X.columns))
X.shape
# Out:
# ['f11', 'f22', 'f82', 'f96', 'f138', 'f156', 'f182', 'f200']
# (3489, 8)

# %% [markdown]
# # Отбор на основе Корреляции #2

# %%
import scipy.stats as stats

# %%
X_wocorr=X

# %%
def get_col(X,threshold):
    for i in X.columns:
        for j in X.columns:
            if i==j: continue
            corr,pvalue= stats.pearsonr(X[i],X[j])
            if abs(corr)>=threshold:
                if midf.loc[i,'mi']>midf.loc[j,'mi']:
                    return j
                else: return i
    return None

# %%
corr_threshold=0.70
col_to_del=get_col(X_wocorr,corr_threshold)
while not (col_to_del==None):
    X_wocorr.drop(labels=col_to_del,axis=1,inplace=True)
    col_to_del=get_col(X_wocorr,corr_threshold)
X_wocorr.shape
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-116-dca6ba1c682c> in <module>()
#       3 while not (col_to_del==None):
#       4     X_wocorr.drop(labels=col_to_del,axis=1,inplace=True)
# ----> 5     col_to_del=get_col(X_wocorr,corr_threshold)
#       6 X_wocorr.shape
#
# <ipython-input-115-ab9832067f30> in get_col(X, threshold)
#       3         for j in X.columns:
#       4             if i==j: continue
# ----> 5             corr,pvalue= stats.pearsonr(X[i],X[j])
#       6             if abs(corr)>=threshold:
#       7                 if midf.loc[i,'mi']>midf.loc[j,'mi']:
#
# C:\Users\Evtisov_SS\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3023     n = len(x)
#    3024     mx = x.mean()
# -> 3025     my = y.mean()
#    3026     xm, ym = x - mx, y - my
#    3027     r_num = np.add.reduce(xm * ym)
#
# C:\Users\Evtisov_SS\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#      63         dtype = mu.dtype('f8')
#      64
# ---> 65     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      66     if isinstance(ret, mu.ndarray):
#      67         ret = um.true_divide(
#
# KeyboardInterrupt:

# %%
X_wocorr.columns

# %%
rf=RandomForestClassifier(max_features='auto',n_estimators=300,max_depth=100,random_state=42)
print (np.mean(cross_val_score(rf, X_wocorr, y, cv=5)))

# %%
midf.loc[['f11', 'f22', 'f82', 'f96', 'f138', 'f152', 'f156', 'f180', 'f182', 'f187', 'f200']]
# Out:
#             mi
# f11   0.058147
# f22   0.075478
# f82   0.089469
# f96   0.070460
# f138  0.150135
# f152  0.034191
# f156  0.069878
# f180  0.043542
# f182  0.040058
# f187  0.032739
# f200  0.073070

# %% [markdown]
# # Проверка на нормальность

# %%
stats.shapiro(stats.boxcox(X['f0']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-f8a6011172c0> in <module>()
# ----> 1 stats.shapiro(stats.boxcox(X['f0']))
#
# C:\Users\Evtisov_SS\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\stats\morestats.py in boxcox(x, lmbda, alpha)
#    1033
#    1034     if any(x <= 0):
# -> 1035         raise ValueError("Data must be positive.")
#    1036
#    1037     if lmbda is not None:  # single transformation
#
# ValueError: Data must be positive.

# %%
from statsmodels.graphics.gofplots import qqplot
qqplot(X['f3'], line='45', fit=True);
plt.show()

# %% [markdown]
# ## лучший набор фич

# %%
best_cols=['f11', 'f22', 'f82', 'f96', 'f138', 'f156', 'f182', 'f200']

# %%
f_classif
# Out:
# <function sklearn.feature_selection.univariate_selection.f_classif>

# %%
from sklearn.feature_selection import f_classif

# %%
f=f_classif(X,y)
fpd=pd.DataFrame(index=X.columns)
fpd.insert(loc=0,column='f',value=f[0])
fpd.insert(loc=0,column='p',value=f[1])
fpd.head()
# Out:
#                 p           f
# f0  3.321544e-186  245.802834
# f1   4.077349e-07    8.861165
# f2   2.055534e-07    9.226298
# f3   1.396780e-04    5.713690
# f4   2.081572e-01    1.471250

# %%
fpd.loc['f196']
# Out:
# p    0.167733
# f    1.614449
# Name: f196, dtype: float64

# %% [markdown]
# # Построим несколько моделей на оставшихся фичах

# %%
rf=RandomForestClassifier(max_features='auto',n_estimators=300,max_depth=100,random_state=42)
print (np.mean(cross_val_score(rf, X, y, cv=5)))
# Out:
# 0.614507490978

# %%
def get_score(clf,X,y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
    cv_score = cross_val_score(clf, X_train, y_train, cv=5).mean()
    print ("CVScore:",cv_score)
    clf.fit(X_train,y_train)
    print ("HoldOut:",clf.score(X_test,y_test))
xgbclf=xgb.XGBClassifier(max_depth=9,colsample_bytree=0.8,min_child_weight=2.0,n_estimators=326,gamma=0.8,subsample=0.5,seed=42)
get_score(xgbclf,X,y)
#CVScore: 0.529079318252
# HoldOut: 0.549188156638
# Out:
# CVScore: 0.572066181112
# HoldOut: 0.574976122254

# %%
X.shape
# Out:
# (3489, 91)

# %% [markdown]
# #  recursive feature elimination.

# %%
from sklearn.feature_selection import RFECV
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import StratifiedKFold

# %%
X=pd.read_csv('x_train.csv',delimiter=";",header=None,names=['f'+str(i) for i in range (223)])
y=pd.read_csv('y_train.csv',names=['class'])
y=y['class']
X_test=pd.read_csv('x_test.csv',delimiter=";",header=None,names=['f'+str(i) for i in range (223)])

# %%
est = RandomForestClassifier(max_features='auto',n_estimators=300,max_depth=100,random_state=42)
rfecv = RFECV(estimator=est, step=1, cv=StratifiedKFold(5),scoring='accuracy')
rfecv.fit(X, y)

print("Optimal number of features : %d" % rfecv.n_features_)

# Plot number of features VS. cross-validation scores
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (nb of correct classifications)")
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.show()
# Out:
# Optimal number of features : 220

# %%
best_ftr_rfe=list(X.columns[rfecv.support_])

# %%
rf=RandomForestClassifier(max_features='auto',n_estimators=300,max_depth=100,random_state=42)
print (np.mean(cross_val_score(rf, X[best_ftr_rfe], y, cv=5)))
# Out:
# 0.568923935405

# %%
xgbclf=xgb.XGBClassifier(max_depth=9,colsample_bytree=0.8,min_child_weight=2.0,n_estimators=326,gamma=0.8,subsample=0.5,seed=42)
get_score(xgbclf,X[best_ftr_rfe],y)
# Out:
# CVScore: 0.533975594372
# HoldOut: 0.562559694365
