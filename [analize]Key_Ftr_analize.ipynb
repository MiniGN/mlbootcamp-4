# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier

# %%
X=pd.read_csv('x_train.csv',delimiter=";",header=None,names=['f'+str(i) for i in range (223)])
y=pd.read_csv('y_train.csv',names=['class'])
y=y['class']
X_test=pd.read_csv('x_test.csv',delimiter=";",header=None,names=['f'+str(i) for i in range (223)])

# %%
data=X_test.join(y)

# %% [markdown]
# ['f138', 'f96', 'f76', 'f11', 'f185', 'f115', 'f131', 'f83']

# %%
col_name='f11'

# %%
sns.distplot(data[data['class']==0][col_name])
sns.distplot(data[data['class']==1][col_name])
sns.distplot(data[data['class']==2][col_name])
sns.distplot(data[data['class']==3][col_name])
sns.distplot(data[data['class']==4][col_name])
plt.show()
# Out:
# C:\Users\Evtisov_SS\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.boxplot(x="class",y=col_name,data=data)
plt.show()

# %%
sns.violinplot(x="class",y=col_name,data=data)
plt.show()

# %%
sns.stripplot(x="class",y=col_name,data=data)
plt.show()

# %%
sns.barplot(x="class",y=col_name,data=data)
plt.show()

# %%
sns.pointplot(x="class",y=col_name,data=data)
plt.show()

# %%
from sklearn.feature_selection import mutual_info_classif,f_classif

# %%
mi=mutual_info_classif(X,y)

# %%
(mi>0.025).sum()
# Out:
# 90

# %%
#X.columns[mi>0.025]
#['f138', 'f96', 'f76', 'f11', 'f185', 'f115', 'f131', 'f83']

# %%
fc=f_classif(X,y)

# %%
(fc[1]<0.05).sum()
# Out:
# 165

# %%
fc[1][83]
# Out:
# 0.00048441777066592925

# %%
np.set_printoptions(threshold=np.inf)

# %%
import scipy.statslinregress as sts

# %%
slope, intercept, r_value, p_value, std_err = sts.linregress(X['f115'], y)
print (r_value,p_value)
# Out:
# -0.0696919150008 3.78740756405e-05

# %%
r_value
# Out:
# -0.069691915000836061

# %%
p_value
# Out:
# 3.7874075640500614e-05
